# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# INFO: Pandarallel will run on 40 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from ect_utils import *

# %%
# %%time
# all flights in the month
flights = load_flights(2018, 9)
# all flight plans in the month
plans = load_plans(2018, 9)
# Out:
# CPU times: user 58 s, sys: 1min 11s, total: 2min 9s
# Wall time: 1min 26s

# %%
flights.head()
# Out:
#     ECTRL ID  ADEP  ADEP Latitude  ADEP Longitude  ADES  ADES Latitude  \
# 0  222570358  HEMA       25.55806        34.58306  LKPR       50.10083
# 1  222570363  LTBA       40.97611        28.81417  LTCG       40.99583
# 2  222570365  GMFF       33.92722        -4.97778  EBBR       50.90139
# 3  222570368  LEPA       39.55167         2.73889  EGKK       51.14806
# 4  222570372  LEPA       39.55167         2.73889  EGTE       50.73417
#
#    ADES Longitude FILED OFF BLOCK TIME   FILED ARRIVAL TIME  \
# 0        14.26000  01-09-2018 00:01:00  01-09-2018 04:13:21
# 1        39.78528  01-09-2018 00:05:00  01-09-2018 01:38:11
# 2         4.48444  01-09-2018 00:05:00  01-09-2018 03:00:43
# 3        -0.19028  01-09-2018 00:05:00  01-09-2018 02:14:50
# 4        -3.41389  01-09-2018 00:05:00  01-09-2018 02:09:59
#
#   ACTUAL OFF BLOCK TIME  ... Actual Distance Flown (nm)               start  \
# 0   01-09-2018 00:21:20  ...                       1801 2018-09-01 00:21:20
# ...

# %%
# %%time
i = 1
flight = flights.loc[i]
plan = load_flight_plan(flight, plans)
track = load_flown_track(flight)
# Out:
# Total files to read: 2
# reading csv file  0 /home/DATA/EUROCONTROL/TRACKS/201809/2018-09-01/2018-09-01_00.csv.gz
# reading csv file  1 /home/DATA/EUROCONTROL/TRACKS/201809/2018-09-01/2018-09-01_01.csv.gz
# CPU times: user 2min 22s, sys: 6.89 s, total: 2min 29s
# Wall time: 2min 23s

# %%
track.head()
# Out:
#          time  icao24        lat        lon   velocity     heading  vertrate  \
# 0  1535761190  4baaaa        NaN        NaN        NaN         NaN       NaN
# 1  1535761191  4baaaa        NaN        NaN  80.294475  358.164225  15.28064
# 2  1535761192  4baaaa        NaN        NaN  80.294475  358.164225  14.95552
# 3  1535761193  4baaaa  40.998835  28.805965  80.294475  358.164225  14.95552
# 4  1535761194  4baaaa  40.998835  28.805965  80.294475  358.164225  14.95552
#
#   callsign  onground  alert    spi  squawk  baroaltitude  geoaltitude  \
# 0      NaN     False  False  False  5115.0        236.22          NaN
# 1      NaN     False  False  False  5115.0        236.22       259.08
# 2      NaN     False  False  False  5115.0        243.84       266.70
# 3      NaN     False  False  False  5115.0        274.32       266.70
# 4      NaN     False  False  False  5115.0        289.56       266.70
#
#    lastposupdate   lastcontact        hour
# ...
